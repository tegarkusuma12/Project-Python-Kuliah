# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# Membaca file CSV yang berisi data pelanggan mall
df = pd.read_csv("C:/Users/ASUS/OneDrive/Ad astra/sales.csv")

# Menampilkan informasi dasar mengenai dataset (kolom, tipe data, nilai null, dll.)
df.info()

# Menampilkan data
display(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SalesID                   999 non-null    int64
#  1   CustomerID                999 non-null    object
#  2   SalesRepID                999 non-null    object
#  3   ProductID                 999 non-null    object
#  4   Sales Quantity (in tons)  999 non-null    int64
#  5   Sales Amount (in US$)     999 non-null    int64
#  6   Year                      999 non-null    int64
#  7   Month                     999 non-null    object
#  8   Day                       999 non-null    int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB
#      SalesID CustomerID SalesRepID ProductID  Sales Quantity (in tons)  \
# 0     210001       R012     BB1988     S2022                        16
# 1     210002       R012     AA1986     S2022                        18
# ...

# %% [markdown]
# - Data Understanding
#
# Pada bagan ini, kita akan mencari insight dari data yang kita miliki. Kita akan melihat apakah data ini telah siap diolah ataukah masih perlu adanya preprocessing.

# %%
df.shape
# Out:
# (999, 9)

# %%
df.describe()
# Out:
#              SalesID  Sales Quantity (in tons)  Sales Amount (in US$)  \
# count     999.000000                999.000000             999.000000
# mean   220381.321321                 11.460460           16858.958959
# std      8608.024066                  7.120786           14568.341376
# min    210001.000000                  1.000000             700.000000
# 25%    210250.500000                  5.000000            6400.000000
# 50%    220141.000000                 10.000000           13000.000000
# 75%    230130.500000                 17.000000           23000.000000
# max    230380.000000                 25.000000           75000.000000
#
#               Year         Day
# count   999.000000  999.000000
# mean   2022.021021   14.336336
# std       0.860255    7.950813
# min    2021.000000    1.000000
# 25%    2021.000000    8.000000
# 50%    2022.000000   14.000000
# 75%    2023.000000   21.000000
# max    2023.000000   28.000000

# %%
df.isna().sum()
# Out:
# SalesID                     0
# CustomerID                  0
# SalesRepID                  0
# ProductID                   0
# Sales Quantity (in tons)    0
# Sales Amount (in US$)       0
# Year                        0
# Month                       0
# Day                         0
# dtype: int64

# %% [markdown]
# # Buat Model

# %%
# Features and target
X = df.drop('Outcome', axis=1)  # Features
y = df['Outcome']  # Target (Outcome)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_36476\1628099283.py in <module>
#       1 # Features and target
# ----> 2 X = df.drop('Outcome', axis=1)  # Features
#       3 y = df['Outcome']  # Target (Outcome)
#
# d:\Anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# d:\Anaconda\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Standardize the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Train the Logistic Regression model
model = LogisticRegression()
model.fit(X_train_scaled, y_train)
