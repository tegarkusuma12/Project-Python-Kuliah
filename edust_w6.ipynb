# %% [markdown]
# # *Data Preparation with Python*

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\asus\onedrive\belajar ngoding\belajar py\.venv\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\asus\onedrive\belajar ngoding\belajar py\.venv\lib\site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\onedrive\belajar ngoding\belajar py\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\onedrive\belajar ngoding\belajar py\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\onedrive\belajar ngoding\belajar py\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\asus\onedrive\belajar ngoding\belajar py\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ##### Membaca data

# %%
import pandas as pd
df = pd.read_csv("D:/Data sets/penduduk_telepon_seluler_pedesaan.csv")
df.tail(1)
# Out:
#                                            nama_series  kode_wilayah wilayah  \
# 524  Proporsi Penduduk yang Memiliki Telepon Selule...            94   Papua
#
#      tahun  nilai  target
# 524   2015  32.51     NaN

# %% [markdown]
# - `;` (titik koma)
# - `\t` (*tab*)
# - `|` (*pipe*)

# %%
df = pd.read_csv("D:/Data sets/penduduk_telepon_seluler_pedesaan.csv")

# %% [markdown]
# `head()` digunkan untuk melihat 5 baris pertama:

# %%
df.head()
# Out:
#                                          nama_series  kode_wilayah    wilayah  \
# 0  Proporsi Penduduk yang Memiliki Telepon Selule...             1  Indonesia
# 1  Proporsi Penduduk yang Memiliki Telepon Selule...             1  Indonesia
# 2  Proporsi Penduduk yang Memiliki Telepon Selule...             1  Indonesia
# 3  Proporsi Penduduk yang Memiliki Telepon Selule...             1  Indonesia
# 4  Proporsi Penduduk yang Memiliki Telepon Selule...             1  Indonesia
#
#    tahun  nilai  target
# 0   2001    NaN   100.0
# 1   2002    NaN   100.0
# 2   2003    NaN   100.0
# 3   2004    NaN   100.0
# 4   2005   8.19   100.0

# %% [markdown]
# `tail()` untuk melihat 5 data urutan bawah.

# %%
df.tail()
# Out:
#     nama_series,kode_wilayah,wilayah,tahun,nilai,target
# 520  Proporsi Penduduk yang Memiliki Telepon Selule...
# 521  Proporsi Penduduk yang Memiliki Telepon Selule...
# 522  Proporsi Penduduk yang Memiliki Telepon Selule...
# 523  Proporsi Penduduk yang Memiliki Telepon Selule...
# 524  Proporsi Penduduk yang Memiliki Telepon Selule...

# %% [markdown]
# Struktur data.
#
# ![Series vs DataFrame](https://storage.googleapis.com/lds-media/images/series-and-dataframe.width-1200.png)
# [*Source*](https://www.learndatasci.com/tutorials/python-pandas-tutorial-complete-introduction-for-beginners/)

# %% [markdown]
# DataFrame info

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nama_series   525 non-null    object
#  1   kode_wilayah  525 non-null    int64
#  2   wilayah       525 non-null    object
#  3   tahun         525 non-null    int64
#  4   nilai         361 non-null    float64
#  5   target        15 non-null     float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 24.7+ KB
# None

# %% [markdown]
# Menghapus Duplikasi

# %%
jumlah_duplikat = df.duplicated().sum()
print(f"Jumlah data duplikat: {jumlah_duplikat}")

df.drop_duplicates(inplace=True)
# Out:
# Jumlah data duplikat: 0

# %% [markdown]
# Mengubah type data

# %%
df['nilai'] = df['nilai'].astype('float64')
df['target'] = df['target'].astype('float64')
df['tahun'] = df['tahun'].astype('int64')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nama_series   525 non-null    object
#  1   kode_wilayah  525 non-null    int64
#  2   wilayah       525 non-null    object
#  3   tahun         525 non-null    int64
#  4   nilai         361 non-null    float64
#  5   target        15 non-null     float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 24.7+ KB
# None

# %% [markdown]
# Mengatasi Missing Values
# - Menghapus baris dengan missing values
# - Mengisi missing values dengan nilai rata-rata

# %%
# Menghapus baris dengan missing values
df_cleaned = df.dropna(subset=['nilai', 'target'])
print(df_cleaned.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 525 entries, 0 to 524
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nama_series   525 non-null    object
#  1   kode_wilayah  525 non-null    int64
#  2   wilayah       525 non-null    object
#  3   tahun         525 non-null    int64
#  4   nilai         525 non-null    float64
#  5   target        525 non-null    float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 28.7+ KB
# None

# %%
# Mengisi missing values dengan nilai rata-rata
df['nilai'] = df['nilai'].fillna(df['nilai'].mean())
df['target'] = df['target'].fillna(df['target'].mean())
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 525 entries, 0 to 524
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nama_series   525 non-null    object
#  1   kode_wilayah  525 non-null    int64
#  2   wilayah       525 non-null    object
#  3   tahun         525 non-null    int64
#  4   nilai         525 non-null    float64
#  5   target        525 non-null    float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 28.7+ KB
# None

# %% [markdown]
# Mengatasi Outliers

# %%
# menggunakan perhitungan outliers
Q1 = df['nilai'].quantile(0.25)
Q3 = df['nilai'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['nilai'] < lower_bound) | (df['nilai'] > upper_bound)]

df_cleaned = df[~df.index.isin(outliers.index)]

print("\nOutliers:")
print(outliers)
# Out:
# Outliers:
# Empty DataFrame
# Columns: [nama_series, kode_wilayah, wilayah, tahun, nilai, target]
# Index: []

# %%
# menentukan batas atas dan bawah
upper_bound = 100
lower_bound = 15

outliers = df[(df['nilai'] < lower_bound) | (df['nilai'] > upper_bound)]

print("\nOutliers:")
outliers
# Out:
# Outliers:
#                                            nama_series  kode_wilayah  \
# 4    Proporsi Penduduk yang Memiliki Telepon Selule...             1
# 5    Proporsi Penduduk yang Memiliki Telepon Selule...             1
# 20   Proporsi Penduduk yang Memiliki Telepon Selule...            11
# 34   Proporsi Penduduk yang Memiliki Telepon Selule...            12
# 35   Proporsi Penduduk yang Memiliki Telepon Selule...            12
# 49   Proporsi Penduduk yang Memiliki Telepon Selule...            13
# 79   Proporsi Penduduk yang Memiliki Telepon Selule...            15
# 80   Proporsi Penduduk yang Memiliki Telepon Selule...            15
# 94   Proporsi Penduduk yang Memiliki Telepon Selule...            16
# 95   Proporsi Penduduk yang Memiliki Telepon Selule...            16
# 109  Proporsi Penduduk yang Memiliki Telepon Selule...            17
# 110  Proporsi Penduduk yang Memiliki Telepon Selule...            17
# 124  Proporsi Penduduk yang Memiliki Telepon Selule...            18
# 125  Proporsi Penduduk yang Memiliki Telepon Selule...            18
# 139  Proporsi Penduduk yang Memiliki Telepon Selule...            19
# 184  Proporsi Penduduk yang Memiliki Telepon Selule...            32
# 185  Proporsi Penduduk yang Memiliki Telepon Selule...            32
# 199  Proporsi Penduduk yang Memiliki Telepon Selule...            33
# 200  Proporsi Penduduk yang Memiliki Telepon Selule...            33
# 229  Proporsi Penduduk yang Memiliki Telepon Selule...            35
# 230  Proporsi Penduduk yang Memiliki Telepon Selule...            35
# 244  Proporsi Penduduk yang Memiliki Telepon Selule...            36
# 245  Proporsi Penduduk yang Memiliki Telepon Selule...            36
# 274  Proporsi Penduduk yang Memiliki Telepon Selule...            52
# 275  Proporsi Penduduk yang Memiliki Telepon Selule...            52
# 289  Proporsi Penduduk yang Memiliki Telepon Selule...            53
# 290  Proporsi Penduduk yang Memiliki Telepon Selule...            53
# 291  Proporsi Penduduk yang Memiliki Telepon Selule...            53
# 304  Proporsi Penduduk yang Memiliki Telepon Selule...            61
# 305  Proporsi Penduduk yang Memiliki Telepon Selule...            61
# 319  Proporsi Penduduk yang Memiliki Telepon Selule...            62
# 320  Proporsi Penduduk yang Memiliki Telepon Selule...            62
# 334  Proporsi Penduduk yang Memiliki Telepon Selule...            63
# 349  Proporsi Penduduk yang Memiliki Telepon Selule...            64
# 379  Proporsi Penduduk yang Memiliki Telepon Selule...            71
# 380  Proporsi Penduduk yang Memiliki Telepon Selule...            71
# 394  Proporsi Penduduk yang Memiliki Telepon Selule...            72
# 395  Proporsi Penduduk yang Memiliki Telepon Selule...            72
# 409  Proporsi Penduduk yang Memiliki Telepon Selule...            73
# 424  Proporsi Penduduk yang Memiliki Telepon Selule...            74
# 425  Proporsi Penduduk yang Memiliki Telepon Selule...            74
# 439  Proporsi Penduduk yang Memiliki Telepon Selule...            75
# 440  Proporsi Penduduk yang Memiliki Telepon Selule...            75
# 455  Proporsi Penduduk yang Memiliki Telepon Selule...            76
# 469  Proporsi Penduduk yang Memiliki Telepon Selule...            81
# 470  Proporsi Penduduk yang Memiliki Telepon Selule...            81
# 471  Proporsi Penduduk yang Memiliki Telepon Selule...            81
# 484  Proporsi Penduduk yang Memiliki Telepon Selule...            82
# 485  Proporsi Penduduk yang Memiliki Telepon Selule...            82
# 486  Proporsi Penduduk yang Memiliki Telepon Selule...            82
# 500  Proporsi Penduduk yang Memiliki Telepon Selule...            91
# 501  Proporsi Penduduk yang Memiliki Telepon Selule...            91
# 514  Proporsi Penduduk yang Memiliki Telepon Selule...            94
# 515  Proporsi Penduduk yang Memiliki Telepon Selule...            94
# 516  Proporsi Penduduk yang Memiliki Telepon Selule...            94
# 517  Proporsi Penduduk yang Memiliki Telepon Selule...            94
#
#                        wilayah  tahun  nilai  target
# 4                    Indonesia   2005   8.19   100.0
# 5                    Indonesia   2006  12.27   100.0
# 20                        Aceh   2006  12.71     NaN
# 34              Sumatera Utara   2005   8.15     NaN
# 35              Sumatera Utara   2006  14.21     NaN
# 49              Sumatera Barat   2005   9.65     NaN
# 79                       Jambi   2005   8.88     NaN
# 80                       Jambi   2006  14.20     NaN
# 94            Sumatera Selatan   2005   5.35     NaN
# 95            Sumatera Selatan   2006   8.38     NaN
# 109                   Bengkulu   2005   4.07     NaN
# 110                   Bengkulu   2006   9.33     NaN
# 124                    Lampung   2005   5.76     NaN
# 125                    Lampung   2006  12.00     NaN
# 139  Kepulauan Bangka Belitung   2005  13.86     NaN
# 184                 Jawa Barat   2005   7.64     NaN
# 185                 Jawa Barat   2006   9.57     NaN
# 199                Jawa Tengah   2005   9.85     NaN
# 200                Jawa Tengah   2006  13.08     NaN
# 229                 Jawa Timur   2005   8.74     NaN
# 230                 Jawa Timur   2006  12.80     NaN
# 244                     Banten   2005   5.83     NaN
# 245                     Banten   2006   8.76     NaN
# 274        Nusa Tenggara Barat   2005   5.32     NaN
# 275        Nusa Tenggara Barat   2006  11.45     NaN
# 289        Nusa Tenggara Timur   2005   1.27     NaN
# 290        Nusa Tenggara Timur   2006   3.76     NaN
# 291        Nusa Tenggara Timur   2007   9.37     NaN
# 304           Kalimantan Barat   2005   6.29     NaN
# 305           Kalimantan Barat   2006  10.92     NaN
# 319          Kalimantan Tengah   2005   4.21     NaN
# 320          Kalimantan Tengah   2006   8.83     NaN
# 334         Kalimantan Selatan   2005  12.22     NaN
# 349           Kalimantan Timur   2005  14.82     NaN
# 379             Sulawesi Utara   2005   8.41     NaN
# 380             Sulawesi Utara   2006  11.29     NaN
# 394            Sulawesi Tengah   2005   3.07     NaN
# 395            Sulawesi Tengah   2006   5.59     NaN
# 409           Sulawesi Selatan   2005   7.35     NaN
# 424          Sulawesi Tenggara   2005   3.21     NaN
# 425          Sulawesi Tenggara   2006   7.39     NaN
# 439                  Gorontalo   2005   4.32     NaN
# 440                  Gorontalo   2006   6.86     NaN
# 455             Sulawesi Barat   2006   7.47     NaN
# 469                     Maluku   2005   2.43     NaN
# 470                     Maluku   2006   4.08     NaN
# 471                     Maluku   2007   7.44     NaN
# 484               Maluku Utara   2005   2.30     NaN
# 485               Maluku Utara   2006   4.73     NaN
# 486               Maluku Utara   2007  11.52     NaN
# 500                Papua Barat   2006   6.05     NaN
# 501                Papua Barat   2007  14.01     NaN
# 514                      Papua   2005   4.61     NaN
# 515                      Papua   2006   4.60     NaN
# 516                      Papua   2007  11.13     NaN
# 517                      Papua   2008  13.50     NaN

# %%
# menghapus data outliers
df_cleaned = df[~df.index.isin(outliers.index)]

# %% [markdown]
# Menyimpan Data yang Sudah Dibersihkan

# %%
df_cleaned.to_csv('data_cleaned.csv', index=False)
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 469 entries, 0 to 524
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nama_series   469 non-null    object
#  1   kode_wilayah  469 non-null    int64
#  2   wilayah       469 non-null    object
#  3   tahun         469 non-null    int64
#  4   nilai         305 non-null    float64
#  5   target        13 non-null     float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 25.6+ KB
